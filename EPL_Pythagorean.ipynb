# %% [markdown]
# # English Premier League (EPL) Pythagorean Predictor

# %% [markdown]
# Load the datafile (this contains 6 variables: the date, home team, away team, goals scored (FTHG), goals against (FTAG) andthe result (H- home win, D- draw, A – away win).
#
# Create a value for a home wins (win= 1, draw=0.5, loss= 0) and away wins and a count variable for each game (=1).
#
# Create a file for games played in 2017 (before date 20180000) and another one for games played in 2018 (after date 20180000).
# For the 2017 games, use .groupby to create a dataframe aggregating by home team the variables for count, home wins, goals for and goals against.  Then, use .groupby to  create a separate dataframe aggregating by away team the variables for count, away wins, goals for and goals against. Rename the variables to denote whether they are aggregates for home team or away team.
#
# Then merge the home and away dataframes.
#
# Sum the values of home and away wins, games, goals for and goals against, then create the values for win percentage (wpc) and the Pythagorean expectation (pyth).
#
# Now repeat steps 4-6 for the 2018 games. Be sure to give different names for wpc and pyth in 2017 and 2018.
#
# Now merge 2017 and 2018 summary files.
#
# Now generate a correlation matrix for the wpc and pyth variables for 2017 and 2018

# %% [markdown]
# ## Step 1

# %%
# Load the packages

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data. 
# EPL results for the 2017/18 season

EPL18 = pd.read_excel('EPL2017-18.xlsx')
print(EPL18.columns.tolist())
# Out:
# ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR']

# %% [markdown]
# ## Step 2

# %%
EPL18['home_win'] = np.where(EPL18['FTHG'] > EPL18['FTAG'], 1, 
                             np.where(EPL18['FTHG'] == EPL18['FTAG'], 0.5, 0))
EPL18['away_win'] = np.where(EPL18['FTHG'] < EPL18['FTAG'], 1, 
                             np.where(EPL18['FTHG'] == EPL18['FTAG'], 0.5, 0))
EPL18['count'] = 1

# %% [markdown]
# ## Step 3

# %% [markdown]
# Create a file for games played in 2017 (before date 20180000) and another one for games played in 2018 (after date 20180000). For the 2017 games, use .groupby to create a dataframe aggregating by home team the variables for count, home wins, goals for and goals against. Then, use .groupby to create a separate dataframe aggregating by away team the variables for count, away wins, goals for and goals against. Rename the variables to denote whether they are aggregates for home team or away team.

# %%
EPL2017 = EPL18[ EPL18['Date'] < 20180000 ]
EPL2018 = EPL18[ EPL18['Date'] >= 20180000 ]

# %%
EPL2017
# Out:
#          Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  home_win  \
# 0    20170811         Arsenal     Leicester     4     3   H       1.0
# 1    20170812        Brighton      Man City     0     2   A       0.0
# 2    20170812         Chelsea       Burnley     2     3   A       0.0
# 3    20170812  Crystal Palace  Huddersfield     0     3   A       0.0
# 4    20170812         Everton         Stoke     1     0   H       1.0
# ..        ...             ...           ...   ...   ...  ..       ...
# 204  20171230      Man United   Southampton     0     0   D       0.5
# 205  20171230       Newcastle      Brighton     0     0   D       0.5
# 206  20171230         Watford       Swansea     1     2   A       0.0
# 207  20171231  Crystal Palace      Man City     0     0   D       0.5
# 208  20171231       West Brom       Arsenal     1     1   D       0.5
#
#      away_win  count
# 0         0.0      1
# 1         1.0      1
# 2         1.0      1
# 3         1.0      1
# 4         0.0      1
# ..        ...    ...
# 204       0.5      1
# 205       0.5      1
# 206       1.0      1
# 207       0.5      1
# 208       0.5      1
#
# [209 rows x 9 columns]

# %%
EPL2018
# Out:
#          Date     HomeTeam      AwayTeam  FTHG  FTAG FTR  home_win  away_win  \
# 209  20180101     Brighton   Bournemouth     2     2   D       0.5       0.5
# 210  20180101      Burnley     Liverpool     1     2   A       0.0       1.0
# 211  20180101      Everton    Man United     0     2   A       0.0       1.0
# 212  20180101    Leicester  Huddersfield     3     0   H       1.0       0.0
# 213  20180101        Stoke     Newcastle     0     1   A       0.0       1.0
# ..        ...          ...           ...   ...   ...  ..       ...       ...
# 375  20180513    Newcastle       Chelsea     3     0   H       1.0       0.0
# 376  20180513  Southampton      Man City     0     1   A       0.0       1.0
# 377  20180513      Swansea         Stoke     1     2   A       0.0       1.0
# 378  20180513    Tottenham     Leicester     5     4   H       1.0       0.0
# 379  20180513     West Ham       Everton     3     1   H       1.0       0.0
#
#      count
# 209      1
# 210      1
# 211      1
# 212      1
# 213      1
# ..     ...
# 375      1
# 376      1
# 377      1
# 378      1
# 379      1
#
# [171 rows x 9 columns]

# %% [markdown]
# ## Step 4 (home team, 2017)

# %%
EPL2017_home = EPL2017[['HomeTeam','FTHG','FTAG','home_win']].copy()
EPL2017_home['home_games']=1
EPL2017_home = EPL2017_home.rename(columns={'HomeTeam':'Team','FTHG':'home_R','FTAG':'home_RA','count':'home_games'})

# %%
EPL2017_home_by_teams = EPL2017_home.groupby('Team')['home_games','home_win','home_R','home_RA'].sum().reset_index()
EPL2017_home_by_teams
# Out:
# C:\Users\hsupo\AppData\Local\Temp\ipykernel_28200\1555406033.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   EPL2017_home_by_teams = EPL2017_home.groupby('Team')['home_games','home_win','home_R','home_RA'].sum().reset_index()
#               Team  home_games  home_win  home_R  home_RA
# 0          Arsenal          10       8.5      25       10
# 1      Bournemouth          11       4.5      14       17
# 2         Brighton          10       5.5      10       12
# 3          Burnley          10       6.0       7        6
# 4          Chelsea          11       8.5      21        7
# 5   Crystal Palace          11       5.0      14       18
# 6          Everton          10       6.5      17       13
# 7     Huddersfield          11       6.0      10       12
# 8        Leicester          10       5.0      13       14
# 9        Liverpool          11       8.5      21        4
# 10        Man City          10       9.5      36        7
# 11      Man United          11       9.0      24        5
# 12       Newcastle          11       4.0       9       13
# 13     Southampton          11       5.0      13       15
# 14           Stoke          10       5.0      13       19
# 15         Swansea          10       3.0       6       15
# 16       Tottenham          10       7.5      21        8
# 17         Watford          11       4.5      14       23
# 18       West Brom          11       4.5      10       15
# 19        West Ham           9       4.0      10       14

# %% [markdown]
# ## Step 5 (home team, 2018)

# %%
EPL2018_home = EPL2018[['HomeTeam','FTHG','FTAG','home_win']].copy()
EPL2018_home['home_games']=1
EPL2018_home = EPL2018_home.rename(columns={'HomeTeam':'Team','FTHG':'home_R','FTAG':'home_RA'})

# %%
EPL2018_home_by_teams = EPL2018_home.groupby('Team')['home_games','home_win','home_R','home_RA'].sum().reset_index()
EPL2018_home_by_teams
# Out:
# C:\Users\hsupo\AppData\Local\Temp\ipykernel_28200\3917387813.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   EPL2018_home_by_teams = EPL2018_home.groupby('Team')['home_games','home_win','home_R','home_RA'].sum().reset_index()
#               Team  home_games  home_win  home_R  home_RA
# 0          Arsenal           9       7.5      29       10
# 1      Bournemouth           8       5.0      12       13
# 2         Brighton           9       5.5      14       13
# 3          Burnley           9       3.5       9       11
# 4          Chelsea           8       4.5       9        9
# 5   Crystal Palace           8       4.5      15        9
# 6          Everton           9       5.5      11        9
# 7     Huddersfield           8       2.5       6       13
# 8        Leicester           9       5.0      12        8
# 9        Liverpool           8       7.0      24        6
# 10        Man City           9       7.5      25        7
# 11      Man United           8       7.0      14        4
# 12       Newcastle           8       6.0      12        4
# 13     Southampton           8       2.5       7       11
# 14           Stoke           9       2.5       7       11
# 15         Swansea           9       4.5      11        9
# 16       Tottenham           9       7.5      19        8
# 17         Watford           8       5.5      13        8
# 18       West Brom           8       3.0      11       14
# 19        West Ham          10       6.0      14       12

# %% [markdown]
# ## Step 6 (home team)

# %% [markdown]
# ## Optional steps, not required for Assessment
# ### (Uncomment to run)

# %%
# Plot the data

#sns.relplot(x="pyth17", y="wpc17", data =EPL17)

# %%
# Run the regression

#pyth_lm = smf.ols(formula = 'wpc17 ~ pyth17', data=EPL17).fit()
#pyth_lm.summary()

# %% [markdown]
# ## Step 7 (=Step 4 (away team, 2017))

# %%
EPL2017_away = EPL2017[['AwayTeam','FTHG','FTAG','away_win']].copy()
EPL2017_away['away_games']=1
EPL2017_away = EPL2017_away.rename(columns={'AwayTeam':'Team','FTAG':'away_R','FTHG':'away_RA'})

# %%
EPL2017_away_by_teams = EPL2017_away.groupby('Team')['away_games','away_win','away_R','away_RA'].sum().reset_index()
EPL2017_away_by_teams
# Out:
# C:\Users\hsupo\AppData\Local\Temp\ipykernel_28200\1931517594.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   EPL2017_away_by_teams = EPL2017_away.groupby('Team')['away_games','away_win','away_R','away_RA'].sum().reset_index()
#               Team  away_games  away_win  away_R  away_RA
# 0          Arsenal          11       5.0      13       16
# 1      Bournemouth          10       3.0       6       15
# 2         Brighton          11       3.0       5       13
# 3          Burnley          11       6.5      11       11
# 4          Chelsea          10       7.0      18        7
# 5   Crystal Palace          10       2.5       4       14
# 6          Everton          11       3.5       8       19
# 7     Huddersfield          10       3.0       8       20
# 8        Leicester          11       5.0      18       18
# 9        Liverpool          10       6.5      27       20
# 10        Man City          11      10.5      25        5
# 11      Man United          10       6.5      19       11
# 12       Newcastle          10       3.0      10       17
# 13     Southampton          10       3.0       7       15
# 14           Stoke          11       2.5      10       27
# 15         Swansea          11       3.0       7       17
# 16       Tottenham          10       5.5      18       12
# 17         Watford          10       4.5      16       14
# 18       West Brom          10       2.5       5       13
# 19        West Ham          11       3.0      12       24

# %% [markdown]
# ## Step 7 (=Step 5 (away team, 2018))

# %%
EPL2018_away = EPL2018[['AwayTeam','FTHG','FTAG','away_win']].copy()
EPL2018_away['away_games']=1
EPL2018_away = EPL2018_away.rename(columns={'AwayTeam':'Team','FTAG':'away_R','FTHG':'away_RA'})
EPL2018_away_by_teams = EPL2018_away.groupby('Team')['away_games','away_win','away_R','away_RA'].sum().reset_index()
EPL2018_away_by_teams
# Out:
# C:\Users\hsupo\AppData\Local\Temp\ipykernel_28200\2885188697.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   EPL2018_away_by_teams = EPL2018_away.groupby('Team')['away_games','away_win','away_R','away_RA'].sum().reset_index()
#               Team  away_games  away_win  away_R  away_RA
# 0          Arsenal           8       1.0       7       15
# 1      Bournemouth           9       4.0      13       16
# 2         Brighton           8       1.5       5       16
# 3          Burnley           8       4.0       9       11
# 4          Chelsea           9       4.5      14       15
# 5   Crystal Palace           9       4.5      12       14
# 6          Everton           8       2.5       8       17
# 7     Huddersfield           9       2.5       4       13
# 8        Leicester           8       2.5      13       20
# 9        Liverpool           9       5.0      12        8
# 10        Man City           8       6.5      20        8
# 11      Man United           9       5.5      11        8
# 12       Newcastle           9       3.0       8       13
# 13     Southampton           9       4.0      10       15
# 14           Stoke           8       3.0       5       11
# 15         Swansea           8       2.0       4       15
# 16       Tottenham           9       6.5      16        8
# 17         Watford           9       0.5       1       19
# 18       West Brom           9       2.5       5       14
# 19        West Ham           8       3.0      12       18

# %% [markdown]
# ## Step 7 (=Step 6 (away team))

# %% [markdown]
# ## Optional steps, not required for Assessment
# ### (Uncomment to run)

# %%
# Plot the data

#sns.relplot(x="pyth18", y="wpc18", data =EPL2018)

# %%
# Run the regression

#pyth_lm = smf.ols(formula = 'wpc18 ~ pyth18', data=EPL2018).fit()
#pyth_lm.summary()

# %% [markdown]
# ## Step 8, 2017 Home + Away

# %%
EPL2017_by_team = pd.merge(EPL2017_home_by_teams,EPL2017_away_by_teams, on='Team')

EPL2017_by_team['R'] = EPL2017_by_team['home_R'] + EPL2017_by_team['away_R']
EPL2017_by_team['RA'] = EPL2017_by_team['home_RA'] + EPL2017_by_team['away_RA']
EPL2017_by_team['pyth17'] = EPL2017_by_team['R']**2 / (EPL2017_by_team['R']**2 + EPL2017_by_team['RA']**2)

EPL2017_by_team['total_wins'] = EPL2017_by_team['home_win'] + EPL2017_by_team['away_win']
EPL2017_by_team['total_games'] = EPL2017_by_team['home_games'] + EPL2017_by_team['away_games']
EPL2017_by_team['wpc17'] = EPL2017_by_team['total_wins'] / EPL2017_by_team['total_games']

EPL2017_by_team
# Out:
#               Team  home_games  home_win  home_R  home_RA  away_games  \
# 0          Arsenal          10       8.5      25       10          11
# 1      Bournemouth          11       4.5      14       17          10
# 2         Brighton          10       5.5      10       12          11
# 3          Burnley          10       6.0       7        6          11
# 4          Chelsea          11       8.5      21        7          10
# 5   Crystal Palace          11       5.0      14       18          10
# 6          Everton          10       6.5      17       13          11
# 7     Huddersfield          11       6.0      10       12          10
# 8        Leicester          10       5.0      13       14          11
# 9        Liverpool          11       8.5      21        4          10
# 10        Man City          10       9.5      36        7          11
# 11      Man United          11       9.0      24        5          10
# 12       Newcastle          11       4.0       9       13          10
# 13     Southampton          11       5.0      13       15          10
# 14           Stoke          10       5.0      13       19          11
# 15         Swansea          10       3.0       6       15          11
# 16       Tottenham          10       7.5      21        8          10
# 17         Watford          11       4.5      14       23          10
# 18       West Brom          11       4.5      10       15          10
# 19        West Ham           9       4.0      10       14          11
#
#     away_win  away_R  away_RA   R  RA    pyth17  total_wins  total_games  \
# 0        5.0      13       16  38  26  0.681132        13.5           21
# 1        3.0       6       15  20  32  0.280899         7.5           21
# 2        3.0       5       13  15  25  0.264706         8.5           21
# 3        6.5      11       11  18  17  0.528548        12.5           21
# 4        7.0      18        7  39  14  0.885847        15.5           21
# 5        2.5       4       14  18  32  0.240356         7.5           21
# 6        3.5       8       19  25  32  0.379018        10.0           21
# 7        3.0       8       20  18  32  0.240356         9.0           21
# 8        5.0      18       18  31  32  0.484131        10.0           21
# 9        6.5      27       20  48  24  0.800000        15.0           21
# 10      10.5      25        5  61  12  0.962743        20.0           21
# 11       6.5      19       11  43  16  0.878385        15.5           21
# 12       3.0      10       17  19  30  0.286281         7.0           21
# 13       3.0       7       15  20  30  0.307692         8.0           21
# 14       2.5      10       27  23  46  0.200000         7.5           21
# 15       3.0       7       17  13  32  0.141660         6.0           21
# 16       5.5      18       12  39  20  0.791775        13.0           20
# 17       4.5      16       14  30  37  0.396651         9.0           21
# 18       2.5       5       13  15  28  0.222993         7.0           21
# 19       3.0      12       24  22  38  0.251037         7.0           20
#
#        wpc17
# 0   0.642857
# 1   0.357143
# 2   0.404762
# 3   0.595238
# 4   0.738095
# 5   0.357143
# 6   0.476190
# 7   0.428571
# 8   0.476190
# 9   0.714286
# 10  0.952381
# 11  0.738095
# 12  0.333333
# 13  0.380952
# 14  0.357143
# 15  0.285714
# 16  0.650000
# 17  0.428571
# 18  0.333333
# 19  0.350000

# %%
EPL2017_by_team['diff'] = EPL2017_by_team['pyth17'] - EPL2017_by_team['wpc17']
EPL2017_by_team.sort_values(by='away_win')
# Out:
#               Team  home_games  home_win  home_R  home_RA  away_games  \
# 5   Crystal Palace          11       5.0      14       18          10
# 14           Stoke          10       5.0      13       19          11
# 18       West Brom          11       4.5      10       15          10
# 19        West Ham           9       4.0      10       14          11
# 1      Bournemouth          11       4.5      14       17          10
# 2         Brighton          10       5.5      10       12          11
# 15         Swansea          10       3.0       6       15          11
# 7     Huddersfield          11       6.0      10       12          10
# 13     Southampton          11       5.0      13       15          10
# 12       Newcastle          11       4.0       9       13          10
# 6          Everton          10       6.5      17       13          11
# 17         Watford          11       4.5      14       23          10
# 0          Arsenal          10       8.5      25       10          11
# 8        Leicester          10       5.0      13       14          11
# 16       Tottenham          10       7.5      21        8          10
# 3          Burnley          10       6.0       7        6          11
# 11      Man United          11       9.0      24        5          10
# 9        Liverpool          11       8.5      21        4          10
# 4          Chelsea          11       8.5      21        7          10
# 10        Man City          10       9.5      36        7          11
#
#     away_win  away_R  away_RA   R  RA    pyth17  total_wins  total_games  \
# 5        2.5       4       14  18  32  0.240356         7.5           21
# 14       2.5      10       27  23  46  0.200000         7.5           21
# 18       2.5       5       13  15  28  0.222993         7.0           21
# 19       3.0      12       24  22  38  0.251037         7.0           20
# 1        3.0       6       15  20  32  0.280899         7.5           21
# 2        3.0       5       13  15  25  0.264706         8.5           21
# 15       3.0       7       17  13  32  0.141660         6.0           21
# 7        3.0       8       20  18  32  0.240356         9.0           21
# 13       3.0       7       15  20  30  0.307692         8.0           21
# 12       3.0      10       17  19  30  0.286281         7.0           21
# 6        3.5       8       19  25  32  0.379018        10.0           21
# 17       4.5      16       14  30  37  0.396651         9.0           21
# 0        5.0      13       16  38  26  0.681132        13.5           21
# 8        5.0      18       18  31  32  0.484131        10.0           21
# 16       5.5      18       12  39  20  0.791775        13.0           20
# 3        6.5      11       11  18  17  0.528548        12.5           21
# 11       6.5      19       11  43  16  0.878385        15.5           21
# 9        6.5      27       20  48  24  0.800000        15.0           21
# 4        7.0      18        7  39  14  0.885847        15.5           21
# 10      10.5      25        5  61  12  0.962743        20.0           21
#
#        wpc17      diff
# 5   0.357143 -0.116787
# 14  0.357143 -0.157143
# 18  0.333333 -0.110340
# 19  0.350000 -0.098963
# 1   0.357143 -0.076244
# 2   0.404762 -0.140056
# 15  0.285714 -0.144055
# 7   0.428571 -0.188215
# 13  0.380952 -0.073260
# 12  0.333333 -0.047053
# 6   0.476190 -0.097173
# 17  0.428571 -0.031921
# 0   0.642857  0.038275
# 8   0.476190  0.007941
# 16  0.650000  0.141775
# 3   0.595238 -0.066690
# 11  0.738095  0.140290
# 9   0.714286  0.085714
# 4   0.738095  0.147752
# 10  0.952381  0.010362

# %% [markdown]
# ## Step 9, 2018 Home + Away

# %%
EPL2018_by_team = pd.merge(EPL2018_home_by_teams,EPL2018_away_by_teams, on='Team')
EPL2018_by_team['R'] = EPL2018_by_team['home_R'] + EPL2018_by_team['away_R']
EPL2018_by_team['RA'] = EPL2018_by_team['home_RA'] + EPL2018_by_team['away_RA']
EPL2018_by_team['pyth18'] = EPL2018_by_team['R']**2 / (EPL2018_by_team['R']**2 + EPL2018_by_team['RA']**2)

EPL2018_by_team['total_wins'] = EPL2018_by_team['home_win'] + EPL2018_by_team['away_win']
EPL2018_by_team['total_games'] = EPL2018_by_team['home_games'] + EPL2018_by_team['away_games']
EPL2018_by_team['wpc18'] = EPL2018_by_team['total_wins'] / EPL2018_by_team['total_games']

EPL2018_by_team
# Out:
#               Team  home_games  home_win  home_R  home_RA  away_games  \
# 0          Arsenal           9       7.5      29       10           8
# 1      Bournemouth           8       5.0      12       13           9
# 2         Brighton           9       5.5      14       13           8
# 3          Burnley           9       3.5       9       11           8
# 4          Chelsea           8       4.5       9        9           9
# 5   Crystal Palace           8       4.5      15        9           9
# 6          Everton           9       5.5      11        9           8
# 7     Huddersfield           8       2.5       6       13           9
# 8        Leicester           9       5.0      12        8           8
# 9        Liverpool           8       7.0      24        6           9
# 10        Man City           9       7.5      25        7           8
# 11      Man United           8       7.0      14        4           9
# 12       Newcastle           8       6.0      12        4           9
# 13     Southampton           8       2.5       7       11           9
# 14           Stoke           9       2.5       7       11           8
# 15         Swansea           9       4.5      11        9           8
# 16       Tottenham           9       7.5      19        8           9
# 17         Watford           8       5.5      13        8           9
# 18       West Brom           8       3.0      11       14           9
# 19        West Ham          10       6.0      14       12           8
#
#     away_win  away_R  away_RA   R  RA    pyth18  total_wins  total_games  \
# 0        1.0       7       15  36  25  0.674649         8.5           17
# 1        4.0      13       16  25  29  0.426330         9.0           17
# 2        1.5       5       16  19  29  0.300333         7.0           17
# 3        4.0       9       11  18  22  0.400990         7.5           17
# 4        4.5      14       15  23  24  0.478733         9.0           17
# 5        4.5      12       14  27  23  0.579491         9.0           17
# 6        2.5       8       17  19  26  0.348120         8.0           17
# 7        2.5       4       13  10  26  0.128866         5.0           17
# 8        2.5      13       20  25  28  0.443577         7.5           17
# 9        5.0      12        8  36  14  0.868633        12.0           17
# 10       6.5      20        8  45  15  0.900000        14.0           17
# 11       5.5      11        8  25  12  0.812744        12.5           17
# 12       3.0       8       13  20  17  0.580552         9.0           17
# 13       4.0      10       15  17  26  0.299482         6.5           17
# 14       3.0       5       11  12  22  0.229299         5.5           17
# 15       2.0       4       15  15  24  0.280899         6.5           17
# 16       6.5      16        8  35  16  0.827144        14.0           18
# 17       0.5       1       19  14  27  0.211892         6.0           17
# 18       2.5       5       14  16  28  0.246154         5.5           17
# 19       3.0      12       18  26  30  0.428934         9.0           18
#
#        wpc18
# 0   0.500000
# 1   0.529412
# 2   0.411765
# 3   0.441176
# 4   0.529412
# 5   0.529412
# 6   0.470588
# 7   0.294118
# 8   0.441176
# 9   0.705882
# 10  0.823529
# 11  0.735294
# 12  0.529412
# 13  0.382353
# 14  0.323529
# 15  0.382353
# 16  0.777778
# 17  0.352941
# 18  0.323529
# 19  0.500000

# %%
EPL2018_by_team['diff'] = EPL2018_by_team['pyth18'] - EPL2018_by_team['wpc18']
EPL2018_by_team.sort_values(by='diff')
# Out:
#               Team  home_games  home_win  home_R  home_RA  away_games  \
# 7     Huddersfield           8       2.5       6       13           9
# 17         Watford           8       5.5      13        8           9
# 6          Everton           9       5.5      11        9           8
# 2         Brighton           9       5.5      14       13           8
# 1      Bournemouth           8       5.0      12       13           9
# 15         Swansea           9       4.5      11        9           8
# 14           Stoke           9       2.5       7       11           8
# 13     Southampton           8       2.5       7       11           9
# 18       West Brom           8       3.0      11       14           9
# 19        West Ham          10       6.0      14       12           8
# 4          Chelsea           8       4.5       9        9           9
# 3          Burnley           9       3.5       9       11           8
# 8        Leicester           9       5.0      12        8           8
# 16       Tottenham           9       7.5      19        8           9
# 5   Crystal Palace           8       4.5      15        9           9
# 12       Newcastle           8       6.0      12        4           9
# 10        Man City           9       7.5      25        7           8
# 11      Man United           8       7.0      14        4           9
# 9        Liverpool           8       7.0      24        6           9
# 0          Arsenal           9       7.5      29       10           8
#
#     away_win  away_R  away_RA   R  RA    pyth18  total_wins  total_games  \
# 7        2.5       4       13  10  26  0.128866         5.0           17
# 17       0.5       1       19  14  27  0.211892         6.0           17
# 6        2.5       8       17  19  26  0.348120         8.0           17
# 2        1.5       5       16  19  29  0.300333         7.0           17
# 1        4.0      13       16  25  29  0.426330         9.0           17
# 15       2.0       4       15  15  24  0.280899         6.5           17
# 14       3.0       5       11  12  22  0.229299         5.5           17
# 13       4.0      10       15  17  26  0.299482         6.5           17
# 18       2.5       5       14  16  28  0.246154         5.5           17
# 19       3.0      12       18  26  30  0.428934         9.0           18
# 4        4.5      14       15  23  24  0.478733         9.0           17
# 3        4.0       9       11  18  22  0.400990         7.5           17
# 8        2.5      13       20  25  28  0.443577         7.5           17
# 16       6.5      16        8  35  16  0.827144        14.0           18
# 5        4.5      12       14  27  23  0.579491         9.0           17
# 12       3.0       8       13  20  17  0.580552         9.0           17
# 10       6.5      20        8  45  15  0.900000        14.0           17
# 11       5.5      11        8  25  12  0.812744        12.5           17
# 9        5.0      12        8  36  14  0.868633        12.0           17
# 0        1.0       7       15  36  25  0.674649         8.5           17
#
#        wpc18      diff
# 7   0.294118 -0.165252
# 17  0.352941 -0.141049
# 6   0.470588 -0.122469
# 2   0.411765 -0.111432
# 1   0.529412 -0.103082
# 15  0.382353 -0.101454
# 14  0.323529 -0.094230
# 13  0.382353 -0.082871
# 18  0.323529 -0.077376
# 19  0.500000 -0.071066
# 4   0.529412 -0.050679
# 3   0.441176 -0.040186
# 8   0.441176  0.002401
# 16  0.777778  0.049366
# 5   0.529412  0.050079
# 12  0.529412  0.051140
# 10  0.823529  0.076471
# 11  0.735294  0.077450
# 9   0.705882  0.162750
# 0   0.500000  0.174649

# %%
EPL2018_by_team['diff_home_vs_away'] = EPL2018_by_team['home_win'] - EPL2018_by_team['away_win']
EPL2018_by_team.sort_values(by='diff_home_vs_away')
# Out:
#               Team  home_games  home_win  home_R  home_RA  away_games  \
# 13     Southampton           8       2.5       7       11           9
# 3          Burnley           9       3.5       9       11           8
# 14           Stoke           9       2.5       7       11           8
# 4          Chelsea           8       4.5       9        9           9
# 5   Crystal Palace           8       4.5      15        9           9
# 7     Huddersfield           8       2.5       6       13           9
# 18       West Brom           8       3.0      11       14           9
# 1      Bournemouth           8       5.0      12       13           9
# 16       Tottenham           9       7.5      19        8           9
# 10        Man City           9       7.5      25        7           8
# 11      Man United           8       7.0      14        4           9
# 9        Liverpool           8       7.0      24        6           9
# 15         Swansea           9       4.5      11        9           8
# 8        Leicester           9       5.0      12        8           8
# 19        West Ham          10       6.0      14       12           8
# 6          Everton           9       5.5      11        9           8
# 12       Newcastle           8       6.0      12        4           9
# 2         Brighton           9       5.5      14       13           8
# 17         Watford           8       5.5      13        8           9
# 0          Arsenal           9       7.5      29       10           8
#
#     away_win  away_R  away_RA   R  RA    pyth18  total_wins  total_games  \
# 13       4.0      10       15  17  26  0.299482         6.5           17
# 3        4.0       9       11  18  22  0.400990         7.5           17
# 14       3.0       5       11  12  22  0.229299         5.5           17
# 4        4.5      14       15  23  24  0.478733         9.0           17
# 5        4.5      12       14  27  23  0.579491         9.0           17
# 7        2.5       4       13  10  26  0.128866         5.0           17
# 18       2.5       5       14  16  28  0.246154         5.5           17
# 1        4.0      13       16  25  29  0.426330         9.0           17
# 16       6.5      16        8  35  16  0.827144        14.0           18
# 10       6.5      20        8  45  15  0.900000        14.0           17
# 11       5.5      11        8  25  12  0.812744        12.5           17
# 9        5.0      12        8  36  14  0.868633        12.0           17
# 15       2.0       4       15  15  24  0.280899         6.5           17
# 8        2.5      13       20  25  28  0.443577         7.5           17
# 19       3.0      12       18  26  30  0.428934         9.0           18
# 6        2.5       8       17  19  26  0.348120         8.0           17
# 12       3.0       8       13  20  17  0.580552         9.0           17
# 2        1.5       5       16  19  29  0.300333         7.0           17
# 17       0.5       1       19  14  27  0.211892         6.0           17
# 0        1.0       7       15  36  25  0.674649         8.5           17
#
#        wpc18      diff  diff_home_vs_away
# 13  0.382353 -0.082871               -1.5
# 3   0.441176 -0.040186               -0.5
# 14  0.323529 -0.094230               -0.5
# 4   0.529412 -0.050679                0.0
# 5   0.529412  0.050079                0.0
# 7   0.294118 -0.165252                0.0
# 18  0.323529 -0.077376                0.5
# 1   0.529412 -0.103082                1.0
# 16  0.777778  0.049366                1.0
# 10  0.823529  0.076471                1.0
# 11  0.735294  0.077450                1.5
# 9   0.705882  0.162750                2.0
# 15  0.382353 -0.101454                2.5
# 8   0.441176  0.002401                2.5
# 19  0.500000 -0.071066                3.0
# 6   0.470588 -0.122469                3.0
# 12  0.529412  0.051140                3.0
# 2   0.411765 -0.111432                4.0
# 17  0.352941 -0.141049                5.0
# 0   0.500000  0.174649                6.5

# %% [markdown]
# Merge 2017, 2018

# %%
EPL_1718 = pd.merge(EPL2017_by_team,EPL2018_by_team, on='Team')

keyvars = EPL_1718[['Team','wpc17','wpc18','pyth17','pyth18']]
keyvars.corr()
# Out:
# C:\Users\hsupo\AppData\Local\Temp\ipykernel_28200\707876499.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   keyvars.corr()
#            wpc17     wpc18    pyth17    pyth18
# wpc17   1.000000  0.756573  0.968204  0.745832
# wpc18   0.756573  1.000000  0.795693  0.955986
# pyth17  0.968204  0.795693  1.000000  0.795331
# pyth18  0.745832  0.955986  0.795331  1.000000

# %%
#sns.relplot(x="pyth17", y="wpc18", data =Half2predictor)

# %%
#sns.relplot(x="wpc17", y="wpc18", data =Half2predictor)

# %% [markdown]
# ## Part 1- Data Coding and Merging

# %%
#Import Libraries

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import NHL Team Data and Display
NHL_Team=pd.read_csv("NHL_team.csv")
display(NHL_Team)
# Out:
#     Unnamed: 0    tid                   name           tname         lname  \
# 0            1      1    Toronto Maple Leafs     Maple Leafs       Toronto
# 1            2      2     Montréal Canadiens       Canadiens      Montréal
# 2            3      4          Winnipeg Jets            Jets      Winnipeg
# 3            4      5    Washington Capitals        Capitals    Washington
# 4            5      6     Chicago Blackhawks      Blackhawks       Chicago
# 5            6      7        St. Louis Blues           Blues     St. Louis
# 6            7      8    Pittsburgh Penguins        Penguins    Pittsburgh
# 7            8     10        Edmonton Oilers          Oilers      Edmonton
# 8            9     11         Calgary Flames          Flames       Calgary
# 9           10     14    Philadelphia Flyers          Flyers  Philadelphia
# 10          11     16        San Jose Sharks          Sharks      San Jose
# ...

# %%
#a) Delete the following variables: “Unnamed:0”, “abbr”, “tname”, “lname”, and “sname”.
NHL_Team.drop(["Unnamed: 0", "abbr", "tname", "lname", "sname"], axis=1, inplace=True)

#b) Rename the variable “name” to “team_name”.
NHL_Team.rename(columns={'name':'team_name'}, inplace=True)

# %%
NHL_Team.head()
# Out:
#    tid            team_name tricode
# 0    1  Toronto Maple Leafs     TOR
# 1    2   Montréal Canadiens     MTL
# 2    4        Winnipeg Jets     WPG
# 3    5  Washington Capitals     WSH
# 4    6   Chicago Blackhawks     CHI

# %%
#Import NHL Competition Data and Display Head
NHL_Competition=pd.read_csv("Assignment Data/Week 2/NHL_competition.csv")
NHL_Competition.head()
# Out:
#    Unnamed: 0  comp_id  year  type                     name  tz  start  end
# 0           1        1  2013     2  2013 NHL Regular Season  ET    NaN  NaN
# 1           2        2  2017     2  2017 NHL Regular Season  ET    NaN  NaN
# 2           3     2453  2013     3         2013 NHL Playoff  ET    NaN  NaN
# 3           4     2541  2017     3         2017 NHL Playoff  ET    NaN  NaN
# 4           5     2661  2012     2  2012 NHL Regular Season  ET    NaN  NaN

# %%
# a) Delete the following variables: “Unnamed: 0”, “tz”, “start”, and “end”
NHL_Competition.drop(["Unnamed: 0", "tz", "start", "end"], axis=1, inplace=True)
# b) Rename the variable “name” to “competition_name”.
NHL_Competition.rename(columns={'name':'competition_name'}, inplace=True)
NHL_Competition.head()
# Out:
#    comp_id  year  type         competition_name
# 0        1  2013     2  2013 NHL Regular Season
# 1        2  2017     2  2017 NHL Regular Season
# 2     2453  2013     3         2013 NHL Playoff
# 3     2541  2017     3         2017 NHL Playoff
# 4     2661  2012     2  2012 NHL Regular Season

# %%
#Import NHL Game Data and Display Head
NHL_Game=pd.read_csv("Assignment Data/Week 2/NHL_game.csv")
NHL_Game.head()
# Out:
#    X  gid  comp_id        date  ascore  hscore  period  status home_away  tid
# 0  1   37        2   10/7/2017     NaN     NaN     NaN     NaN      away   25
# 1  2   67        2   10/9/2017     NaN     NaN     NaN     NaN      away   29
# 2  3  154        1  10/14/2013     NaN     NaN     NaN     NaN      away   29
# 3  4  278        1  10/24/2013     NaN     NaN     NaN     NaN      away   53
# 4  5  291        1  10/25/2013     NaN     NaN     NaN     NaN      away    5

# %%
#a) Delete the following variables: “X”, “period”, and “status”.
NHL_Game.drop(["X", "period", "status"], axis=1, inplace=True)
NHL_Game.head()
# Out:
#    gid  comp_id        date  ascore  hscore home_away  tid
# 0   37        2   10/7/2017     NaN     NaN      away   25
# 1   67        2   10/9/2017     NaN     NaN      away   29
# 2  154        1  10/14/2013     NaN     NaN      away   29
# 3  278        1  10/24/2013     NaN     NaN      away   53
# 4  291        1  10/25/2013     NaN     NaN      away    5

# %%
#Merge the dataframe “NHL_Team” into the dataframe “NHL_Game” by “tid.” Continue to name the merged dataframe as “NHL_Game.”
NHL_Game = pd.merge(NHL_Team,NHL_Game, on='tid')
NHL_Game.head()
# Out:
#    tid            team_name tricode   gid  comp_id        date  ascore  \
# 0    1  Toronto Maple Leafs     TOR   741        1  11/28/2013     NaN
# 1    1  Toronto Maple Leafs     TOR   782        1   12/1/2013     NaN
# 2    1  Toronto Maple Leafs     TOR  5225     5181   4/25/2017     NaN
# 3    1  Toronto Maple Leafs     TOR  6557     5385    1/7/2016     NaN
# 4    1  Toronto Maple Leafs     TOR  6914     5385    2/7/2016     NaN
#
#    hscore home_away
# 0     NaN      away
# 1     NaN      away
# 2     NaN      away
# 3     NaN      away
# 4     NaN      away

# %%
# Merge the dataframe “NHL_Competition” into the dataframe “NHL_Game” by “comp_id.”
# Continue to name the merged dataframe as “NHL_Game.”
NHL_Game = pd.merge(NHL_Competition,NHL_Game, on='comp_id')
NHL_Game.head()
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 0        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 1        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid        date  ascore  hscore home_away
# 0     TOR   741  11/28/2013     NaN     NaN      away
# 1     TOR   782   12/1/2013     NaN     NaN      away
# 2     TOR  1003  12/17/2013     1.0     3.0      away
# 3     TOR  1552   1/26/2014     4.0     5.0      away
# 4     TOR  1811    3/2/2014     3.0     4.0      away

# %%
# In the merged “NHL_Game” dataframe, 
# create a variable “hgd” to indicate the goal difference between home
# and away score (hscore – ascore) and delete observations with missing value in the variable “hgd”.
NHL_Game["hgd"] = NHL_Game["hscore"] - NHL_Game["ascore"]
NHL_Game.dropna(subset=["hgd"], inplace=True)
NHL_Game.head()
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid        date  ascore  hscore home_away  hgd
# 2     TOR  1003  12/17/2013     1.0     3.0      away  2.0
# 3     TOR  1552   1/26/2014     4.0     5.0      away  1.0
# 4     TOR  1811    3/2/2014     3.0     4.0      away  1.0
# 5     TOR  1940   3/11/2014     3.0     1.0      away -2.0
# 6     TOR  1522   1/24/2014     1.0     7.0      away  6.0

# %%
# Drop all observations with missing values, if there is still any, from the “NHL_Game” dataframe.
NHL_Game.dropna(inplace=True)
NHL_Game.shape
# Out:
# (18506, 13)

# %%
# Convert the type of the “date” variable from “object” to “datetime.”
NHL_Game['date']=pd.to_datetime(NHL_Game['date'])
NHL_Game.head(5)

# date range
earliest_date = NHL_Game['date'].min()
latest_date = NHL_Game['date'].max()
date_range = (latest_date - earliest_date).days
print(earliest_date,latest_date)
date_range
# Out:
# 2010-10-07 00:00:00 2018-06-08 00:00:00
# 2801

# %%
# Sort the NHL games by “date” and show the first 15 observations.
NHL_Game = NHL_Game.sort_values(by='date')
NHL_Game.head(16)

#fifth_gid = NHL_Game.iloc[4]['gid']   # 5th observation (index starts at 0)
#tenth_gid = NHL_Game.iloc[9]['gid']   # 10th observation
#fifteenth_gid = NHL_Game.iloc[14]['gid']
#fifteenth_gid
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 14163     5662  2010     2  2010 NHL Regular Season   14
# 15794     5662  2010     2  2010 NHL Regular Season   66
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13611     5662  2010     2  2010 NHL Regular Season    2
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
# 14664     5662  2010     2  2010 NHL Regular Season   21
# 13672     5662  2010     2  2010 NHL Regular Season    5
# 15145     5662  2010     2  2010 NHL Regular Season   35
# 13770     5662  2010     2  2010 NHL Regular Season    6
# 15112     5662  2010     2  2010 NHL Regular Season   32
# 14056     5662  2010     2  2010 NHL Regular Season   10
# 14460     5662  2010     2  2010 NHL Regular Season   18
# ...

# %%
#Create two dataframes that separate the “NHL_Game” dataframe by home and away games.
# Name them “NHL_Home” and “NHL_Away”, respectively.
NHL_Home = NHL_Game[NHL_Game["home_away"] == "home"]
NHL_Away = NHL_Game[NHL_Game["home_away"] == "away"]

print(NHL_Home.head(5), NHL_Away.head(5))
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
#
#                    team_name tricode   gid       date  ascore  hscore  \
# 15183         Minnesota Wild     MIN  5666 2010-10-07     4.0     3.0
# 13955    Pittsburgh Penguins     PIT  5664 2010-10-07     3.0     2.0
# 13564    Toronto Maple Leafs     TOR  5662 2010-10-07     2.0     3.0
# 14796     Colorado Avalanche     COL  5668 2010-10-08     3.0     4.0
# 15675  Columbus Blue Jackets     CBJ  5672 2010-10-08     3.0     2.0
#
#       home_away  hgd
# 15183      home -1.0
# 13955      home -1.0
# 13564      home  1.0
# 14796      home  1.0
# ...

# %%
# a) Rename variables:
#      i) For away games, rename “ascore” to “goals_for”; rename “hscore” to “goals_against”
#     ii) For home games, rename “hscore” to “goals_for”; rename “ascore” to “goals_against” 
NHL_Home.rename(columns={'hscore':'goals_for', 'ascore':'goals_against'}, inplace=True)
NHL_Away.rename(columns={'hscore':'goals_against', 'ascore':'goals_for'}, inplace=True)


# b) Create a “win” variable that equals to 1 if the team won the game;
#                                           0 if the team lost the game; and 0.5 if it was a draw. 
NHL_Home["win"] = np.where(NHL_Home["goals_for"] > NHL_Home["goals_against"], 1, 
                             np.where(NHL_Home["goals_for"] == NHL_Home["goals_against"], 0.5, 0))
NHL_Away["win"] = np.where(NHL_Away["goals_for"] > NHL_Away["goals_against"], 1, 
                             np.where(NHL_Away["goals_for"] == NHL_Away["goals_against"], 0.5, 0))

NHL_Home.head(5)
NHL_Away.head(5)
# Out:
#        comp_id  year  type         competition_name  tid            team_name  \
# 14163     5662  2010     2  2010 NHL Regular Season   14  Philadelphia Flyers
# 15794     5662  2010     2  2010 NHL Regular Season   66  Carolina Hurricanes
# 13611     5662  2010     2  2010 NHL Regular Season    2   Montréal Canadiens
# 14664     5662  2010     2  2010 NHL Regular Season   21        Anaheim Ducks
# 13672     5662  2010     2  2010 NHL Regular Season    5  Washington Capitals
#
#       tricode   gid       date  goals_for  goals_against home_away  hgd  win
# 14163     PHI  5664 2010-10-07        3.0            2.0      away -1.0  1.0
# 15794     CAR  5666 2010-10-07        4.0            3.0      away -1.0  1.0
# 13611     MTL  5662 2010-10-07        2.0            3.0      away  1.0  0.0
# 14664     ANA  5679 2010-10-08        0.0            4.0      away  4.0  0.0
# 13672     WSH  5683 2010-10-08        2.0            4.0      away  2.0  0.0

# %%
# Append the “NHL_Home” and “NHL_Away” dataframes to be the new “NHL_Game” dataframe.
NHL_Game=pd.concat([NHL_Home, NHL_Away], axis=0)
NHL_Game.head()
# Out:
#        comp_id         competition_name       date   gid  goals_against  \
# 15183     5662  2010 NHL Regular Season 2010-10-07  5666            4.0
# 13955     5662  2010 NHL Regular Season 2010-10-07  5664            3.0
# 13564     5662  2010 NHL Regular Season 2010-10-07  5662            2.0
# 14796     5662  2010 NHL Regular Season 2010-10-08  5668            3.0
# 15675     5662  2010 NHL Regular Season 2010-10-08  5672            3.0
#
#        goals_for  hgd home_away              team_name  tid tricode  type  \
# 15183        3.0 -1.0      home         Minnesota Wild   35     MIN     2
# 13955        2.0 -1.0      home    Pittsburgh Penguins    8     PIT     2
# 13564        3.0  1.0      home    Toronto Maple Leafs    1     TOR     2
# 14796        4.0  1.0      home     Colorado Avalanche   22     COL     2
# 15675        2.0 -1.0      home  Columbus Blue Jackets   52     CBJ     2
#
#        win  year
# 15183  0.0  2010
# 13955  0.0  2010
# 13564  1.0  2010
# ...

# %%
# Generate a team level dataframe that aggregates the total number of games won, 
# the total number of “goals_for” and “goals_against” for each team in each competition 
# (i.e. grouped by tid, competition_name and type). Name this new dataframe “NHL_Team_Stats”. 
# Make sure to convert the indexes of the new dataframe back as variables. 
NHL_Team_Stats = NHL_Game.groupby(["tid","competition_name","type"])[['win','goals_for','goals_against']].sum()
NHL_Team_Stats.reset_index(inplace=True)
NHL_Team_Stats.head()
# Out:
#    tid         competition_name  type   win  goals_for  goals_against
# 0    1  2010 NHL Regular Season     2  36.0      223.0          259.0
# 1    1  2011 NHL Regular Season     2  20.0      129.0          129.0
# 2    1         2012 NHL Playoff     3   3.0       18.0           22.0
# 3    1  2012 NHL Regular Season     2  25.0      144.0          129.0
# 4    1  2013 NHL Regular Season     2  38.0      231.0          250.0

# %%
# Create a dataframe “NHL_Game_Count” that include the total number of games played by each team in each competition 
# (i.e. grouped by tid, competition_name and type). 
# Name this new variable in the dataframe “game_count”.
NHL_Game_Count =  NHL_Game.groupby(["tid","competition_name","type"])[['date']].count()
NHL_Game_Count.rename(columns={"date":"game_count"}, inplace=True)
NHL_Game_Count
# Out:
#                                     game_count
# tid   competition_name        type
# 1     2010 NHL Regular Season 2             82
#       2011 NHL Regular Season 2             40
#       2012 NHL Playoff        3              7
#       2012 NHL Regular Season 2             46
#       2013 NHL Regular Season 2             79
#       2014 NHL Regular Season 2             78
#       2015 NHL Regular Season 2             79
#       2016 NHL Playoff        3              6
#       2016 NHL Regular Season 2             82
#       2017 NHL Playoff        3              7
#       2017 NHL Regular Season 2             79
# 2     2010 NHL Playoff        3              7
#       2010 NHL Regular Season 2             79
#       2011 NHL Regular Season 2             39
#       2012 NHL Playoff        3              5
#       2012 NHL Regular Season 2             48
#       2013 NHL Playoff        3             17
#       2013 NHL Regular Season 2             81
# ...

# %%
# Merge dataframes.
# a) Merge the “NHL_Game_Count” dataframe into the “NHL_Team_Stats” dataframe
#    by “tid”, “competition_name”, and “type”. Continue to name the merged dataframe “NHL_Team_Stats”.
NHL_Team_Stats = pd.merge(NHL_Team_Stats,NHL_Game_Count, on=['tid','competition_name','type'])
NHL_Team_Stats.head()

# b) Merge the “NHL_Team” dataframe into the “NHL_Team_Stats” dataframe by “tid”. 
#    Continue to name the merged dataframe “NHL_Team_Stats”.
NHL_Team_Stats = pd.merge(NHL_Team, NHL_Team_Stats, on='tid')
NHL_Team_Stats.head()
# Out:
#    tid            team_name tricode         competition_name  type   win  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2  36.0
# 1    1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2  20.0
# 2    1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3   3.0
# 3    1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2  25.0
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2  38.0
#
#    goals_for  goals_against  game_count
# 0      223.0          259.0          82
# 1      129.0          129.0          40
# 2       18.0           22.0           7
# 3      144.0          129.0          46
# 4      231.0          250.0          79

# %%
#Import NHL PPPK Data and Display Head
NHL_PPPK=pd.read_csv("Assignment Data/Week 2/pp.pk.ppgf.csv")
NHL_PPPK.head()
# Out:
#   tricode   pp   pk  ppgf  competition_name
# 0     ANA   35   27   9.0  2010 NHL Playoff
# 1     BOS  126  116  22.0  2010 NHL Playoff
# 2     BUF   48   46  13.0  2010 NHL Playoff
# 3     CHI   27   39   6.0  2010 NHL Playoff
# 4     DET   59   55   6.0  2010 NHL Playoff

# %%
# Import the “pp.pk.ppgf.csv” data file and name the dataframe as “NHL_PPPK” in Jupyter Notebook. 
# Merge the “NHL_PPPK” dataframe into the “NHL_Team_Stats” dataframe by “tricode” and “competition_name”.
NHL_Team_Stats = pd.merge(NHL_Team_Stats, NHL_PPPK, on=['tricode','competition_name'])
NHL_Team_Stats.head()
# Out:
#    tid            team_name tricode         competition_name  type   win  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2  36.0
# 1    1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2  20.0
# 2    1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3   3.0
# 3    1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2  25.0
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2  38.0
#
#    goals_for  goals_against  game_count   pp   pk  ppgf
# 0      223.0          259.0          82  368  426  46.0
# 1      129.0          129.0          40  192  182  36.0
# 2       18.0           22.0           7   30   29   5.0
# 3      144.0          129.0          46  234  230  39.0
# 4      231.0          250.0          79  362  342  61.0

# %%
#Create new variables in the “NHL_Team_Stats” dataframe.
#a) Winning percentage (“win_pct”)=”win”/ total number of games played
NHL_Team_Stats["win_pct"] = NHL_Team_Stats["win"]/NHL_Team_Stats["game_count"]
#b) Average goals for per game (“avg_gf”)=total number of goals for / total number of games played 
NHL_Team_Stats["avg_gf"] = NHL_Team_Stats["goals_for"]/NHL_Team_Stats["game_count"]
#c) Average goals against per game (“avg_ga”)=total number of goals against / total number of games played
NHL_Team_Stats["avg_ga"] = NHL_Team_Stats["goals_against"]/NHL_Team_Stats["game_count"]
NHL_Team_Stats.head()
# Out:
#    tid            team_name tricode         competition_name  type   win  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2  36.0
# 1    1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2  20.0
# 2    1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3   3.0
# 3    1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2  25.0
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2  38.0
#
#    goals_for  goals_against  game_count   pp   pk  ppgf   win_pct    avg_gf  \
# 0      223.0          259.0          82  368  426  46.0  0.439024  2.719512
# 1      129.0          129.0          40  192  182  36.0  0.500000  3.225000
# 2       18.0           22.0           7   30   29   5.0  0.428571  2.571429
# 3      144.0          129.0          46  234  230  39.0  0.543478  3.130435
# 4      231.0          250.0          79  362  342  61.0  0.481013  2.924051
#
#      avg_ga
# 0  3.158537
# 1  3.225000
# 2  3.142857
# 3  2.804348
# ...

# %%
# In the “NHL_Competition” dataframe, the variable “type” indicates the type of competition: type=2 – regular season. 
# Create a dataframe that contains team statistics for games only during regular seasons. 
# Name this dataframe “NHL_Team_R_Stats”. 
NHL_Team_R_Stats = NHL_Team_Stats[NHL_Team_Stats["type"]==2]
NHL_Team_R_Stats
# Out:
#        tid              team_name tricode         competition_name  type  \
# 0        1    Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1        1    Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 3        1    Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4        1    Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5        1    Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6        1    Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 8        1    Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# 10       1    Toronto Maple Leafs     TOR  2017 NHL Regular Season     2
# 12       2     Montréal Canadiens     MTL  2010 NHL Regular Season     2
# 13       2     Montréal Canadiens     MTL  2011 NHL Regular Season     2
# 15       2     Montréal Canadiens     MTL  2012 NHL Regular Season     2
# 17       2     Montréal Canadiens     MTL  2013 NHL Regular Season     2
# ...

# %% [markdown]
# ## Part 2 - Descriptive and Summary Analyses

# %%
# In the “NHL_Game” dataframe, calculate summary statistics for the  “goals_for” variable; 
goals_for_summary = NHL_Game["goals_for"].describe()
goals_for_summary
# Out:
# count    18506.000000
# mean         2.825894
# std          1.654729
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: goals_for, dtype: float64

# %%
# calculate summary statistics for the “goals_against” variable based on whether it is home or away game.
goals_against_summary = NHL_Game.groupby("home_away")["goals_against"].describe()
goals_against_summary
# Out:
#             count      mean       std  min  25%  50%  75%   max
# home_away
# away       9253.0  2.961958  1.688463  0.0  2.0  3.0  4.0  10.0
# home       9253.0  2.689830  1.608916  0.0  1.0  3.0  4.0  10.0

# %%
#Create a histogram of the “goals_against” variable by whether the game is home or away 
#a) Make the color of the histogram green
#b) Set the number of bins to be 20
#c) Make sure the two sub-histograms share the same ranges for the x-axis and y-axis.
NHL_Game.hist(by='home_away', column='goals_against', bins=20, color='green', sharex=True, sharey=True)
plt.savefig('FG3_PCT_Distribution.png')

# %% [markdown]
# ## Part 3 - Correlation Analyses

# %%
# In the “NHL_Team_R_Stats” dataframe, make a scatter plot to depict the relationship
# between the total number of goals for and the winning percentage. 
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
plt.scatter(NHL_Team_R_Stats['goals_for'], NHL_Team_R_Stats['win_pct'])
# b) Add a regression line to the scatter plot.
sns.regplot(x='goals_for', y='win_pct', data=NHL_Team_R_Stats)
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
plt.title('Total Goals for vs. Winning Percentage', fontsize=11)
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.show()

# %%
# In the “NHL_Team_R_Stats” dataframe, calculate the correlation coefficient 
# between total number of goals for and winning percentage.
NHL_Team_R_Stats['win_pct'].corr(NHL_Team_R_Stats['goals_for'])
# Out:
# 0.31566456280848143

# %%
# Create a scatter plot of the total number of goals for and winning percentage similar to step 1 for regular season games.
# In this graph, group observations by “competition_name”.
color_labels = NHL_Team_R_Stats['competition_name'].unique()
rgb_values = sns.color_palette("Set1", len(color_labels))
color_map = dict(zip(color_labels, rgb_values))

# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
plt.scatter(NHL_Team_R_Stats['goals_for'], NHL_Team_R_Stats['win_pct'], c=NHL_Team_R_Stats['competition_name'].map(color_map))
# b) Add a regression line to the scatter plot.
sns.lmplot(x='goals_for', y='win_pct', data=NHL_Team_R_Stats, hue='competition_name', palette=color_map)
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
plt.title('Total Goals for vs. Winning Percentage', fontsize=11)
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.show()

# %%
# For the “NHL_Team_R_Stats” dataframe, delete observations of 2011 and 2012 seasons.
# Continue to name the dataframe “NHL_Team_R_Stats”.
NHL_Team_R_Stats = NHL_Team_R_Stats[~NHL_Team_R_Stats['competition_name'].isin(["2011 NHL Regular Season", "2012 NHL Regular Season"])]
NHL_Team_R_Stats
# Out:
#        tid              team_name tricode         competition_name  type  \
# 0        1    Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 4        1    Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5        1    Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6        1    Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 8        1    Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# 10       1    Toronto Maple Leafs     TOR  2017 NHL Regular Season     2
# 12       2     Montréal Canadiens     MTL  2010 NHL Regular Season     2
# 17       2     Montréal Canadiens     MTL  2013 NHL Regular Season     2
# 19       2     Montréal Canadiens     MTL  2014 NHL Regular Season     2
# 20       2     Montréal Canadiens     MTL  2015 NHL Regular Season     2
# 22       2     Montréal Canadiens     MTL  2016 NHL Regular Season     2
# 23       2     Montréal Canadiens     MTL  2017 NHL Regular Season     2
# ...

# %%
# In the new “NHL_Team_R_Stats” dataframe, create a scatter plot of total number of goals for and winning percentage.
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
plt.scatter(NHL_Team_R_Stats['goals_for'], NHL_Team_R_Stats['win_pct'])
# b) Add a regression line to the scatter plot.
sns.regplot(x='goals_for', y='win_pct', data=NHL_Team_R_Stats)
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
plt.title('Total Goals for vs. Winning Percentage', fontsize=11)
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.show()

# %%
# Calculate the correlation coefficient between total number of goals for and winning percentage 
# in the updated “NHL_Team_R_Stats” dataframe.
NHL_Team_R_Stats['win_pct'].corr(NHL_Team_R_Stats['goals_for'])
# Out:
# 0.7706255321801442

# %% [markdown]
# ## Uncomment this Section once your assignment is complete

# %%
#Save Dataframes as .csv files
#NHL_Game.to_csv("NHL_Game2.csv", index=False)
#NHL_Team_Stats.to_csv("NHL_Team_Stats.csv", index=False)
#NHL_Team_R_Stats.to_csv("NHL_Team_R_Stats.csv", index=False)
